# %% [markdown]
# # 00 - Transformação Avançada de Categóricas com Likelihood e P-value

# %% [markdown]
# ## Introdução

# %% [markdown]
# Nesse trabalho queremos saber qual a probabilidade de uma pergunta ser de alta qualidade com base nas tags da pergunta.

# %% [markdown]
# ## Importação

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import re

# %% [markdown]
# ## Pré-processamento dos dados

# %%
data = pd.read_csv("data-raw/train.csv", parse_dates=['CreationDate'])
data = data.sort_values("CreationDate")
data.head()
# Out:
#          Id                                              Title  \
# 0  34552656             Java: Repeat Task Every Random Seconds
# 1  34553034                  Why are Java Optionals immutable?
# 2  34553174  Text Overlay Image with Darkened Opacity React...
# 3  34553318         Why ternary operator in swift is so picky?
# 4  34553755                 hide/show fab with scale animation
#
#                                                 Body  \
# 0  <p>I'm already familiar with repeating tasks e...
# 1  <p>I'd like to understand why Java 8 Optionals...
# 2  <p>I am attempting to overlay a title over an ...
# 3  <p>The question is very simple, but I just cou...
# 4  <p>I'm using custom floatingactionmenu. I need...
#
#                                                 Tags        CreationDate  \
# 0                                     <java><repeat> 2016-01-01 00:21:59
# 1                                   <java><optional> 2016-01-01 02:03:20
# 2  <javascript><overlay><react-native><opa... 2016-01-01 02:48:24
# 3  <swift><operators><whitespace><ternary-operato... 2016-01-01 03:30:17
# 4  <android><material-design><floating-action-but... 2016-01-01 05:21:48
#
#           Y
# 0  LQ_CLOSE
# 1        HQ
# 2        HQ
# 3        HQ
# 4        HQ

# %%
new_data = []
for ts, tags, y in data[['CreationDate','Tags', 'Y']].values:
    tags_ = re.findall("<([\w\d\-]+)", tags)
    y_ = 1 if 'HQ' in y else 0 
    
    data_pt = [ts, tags_, y_]
    new_data.append(data_pt)

# %% [markdown]
# Vamos fazer 3 separações de dados. Devemos tomar cuidado com o vazamento de dados, onde corremos o risco de apresentar dados ao modelo que não teriamos na produção nesse momento.

# %%
like = new_data[:20000]
train = new_data[20000:40000]
test = new_data[40000:]

# %%
like[0]
# Out:
# [Timestamp('2016-01-01 00:21:59'), ['java', 'repeat'], 0]

# %% [markdown]
# ## Likelihood

# %% [markdown]
# Qual a proporção de vezes que uma tag aparece em uma pergunta que foi de alta qualidade? Ou seja, probabilidade de uma pergunta ser de alta qualidade, dado que ela tem uma tag xpto.
#
# Vamos calcular pegando todos os exemplos positivos da tag sobre todos os exemplos da tag.

# %%
global_like = 0

tag_like_y = dict()
tag_like_num = dict()

for ts, tags, y  in like:
    global_like += y
    
    for t in tags:
        tag_like_y[t] = tag_like_y.get(t, 0) + y
        tag_like_num[t] = tag_like_num.get(t, 0) + 1

# %%
tag_like = dict()

for tag in tag_like_num.keys():
    tag_like[tag] = tag_like_y[tag] / tag_like_num[tag]

# %% [markdown]
# ## Bias Factor

# %% [markdown]
# Comparado a probabilidade aleatório, qual a probabilidade de uma tag especifica ser de alta qualidade.

# %%
global_bias = global_like / 20000
    
tag_bias_factor = dict()
for tag, bias in tag_like.items():
    tag_bias_factor[tag] = bias / global_bias

# %% [markdown]
# ## P-valor

# %% [markdown]
# Checa se a probabilidade acima não foi apenas pelo acaso. Verifica a significancia.

# %%
from scipy.stats import binom

# %%
tag_pvals = dict()
global_bias = 0.4093

for tag in tag_like_num.keys():
    k = tag_like_y[tag]
    n = tag_like_num[tag]
    tag_pvals[tag] = np.min([binom.cdf(k=k, n=n, p=global_bias), binom.sf(k=k-1, n=n, p=global_bias)])
    
tag_pvals
# Out:
# {'java': 9.777594299743535e-82,
#  'repeat': 0.34892649,
#  'optional': 0.028682670309242264,
#  'javascript': 4.826000894975935e-07,
#  'image': 0.22410331283204216,
#  'overlay': 0.365442285286,
#  'react-native': 3.524430726726627e-67,
#  'opacity': 0.65107351,
#  'swift': 1.8465129525956367e-11,
#  'operators': 0.026341674852645304,
#  'whitespace': 0.4749587118995165,
#  'ternary-operator': 0.365442285286,
#  'android': 0.48507856654588277,
#  'material-design': 0.014403741581310844,
#  'floating-action-button': 0.365442285286,
#  'c': 6.086308533874862e-126,
#  'pointers': 2.0150464388807798e-13,
#  'data-structures': 0.025141917206355335,
#  'jquery': 7.623679431434003e-62,
#  'jquery-ui': 0.2962612280941942,
#  'html': 1.3208534471773006e-75,
#  'css': 1.6174537564414793e-25,
#  'twitter-bootstrap': 0.016342419387422202,
#  'windows-10': 0.09626227879450157,
#  'windows-10-mobile': 0.4093,
#  'windows-10-universal': 0.068568592357,
#  'vb6': 0.3210782967714346,
#  'linux': 0.0026336869669543084,
#  'mongodb': 5.961721467962766e-09,
#  'ubuntu': 0.01156932612855378,
#  'ubuntu-14': 0.19230405691058897,
#  'startup': 0.5408055756991601,
#  'android-file': 0.34892649,
#  'ios': 1.0300707492809915e-16,
#  'storyboard': 0.3210782967714346,
#  'uilabel': 0.5879939137881143,
#  'cocoapods': 3.3401790714806025e-06,
#  'haskell': 0.0033003485560100217,
#  'cabal': 0.4093,
#  'haskell-stack': 0.028065124851720098,
#  'arrays': 3.702947025177055e-45,
#  'standard-library': 0.16752649,
#  'amazon-web-services': 6.388585018175319e-26,
#  'amazon-ec2': 3.5165616887142835e-05,
#  'amazon-elastic-beanstalk': 0.001648698186295978,
#  'arduino': 0.015314744650508146,
#  'bluebird': 0.028065124851720098,
#  'powershell': 0.5470657212704588,
#  'temporary-directory': 0.4093,
#  'multithreading': 0.1272603422362945,
#  'stopwatch': 0.34892649,
#  'console': 0.08155562886272506,
#  'vbscript': 0.00039746940080971014,
#  'scala': 1.3904164658250095e-07,
#  'static-analysis': 0.16752649,
#  'case-class': 0.4093,
#  'scala-wartremover': 0.4093,
#  'compiler-errors': 5.967157126058474e-05,
#  'kotlin': 2.579327866586047e-33,
#  'enums': 0.0068330755693699575,
#  'integer': 0.0004924630250927411,
#  'int': 0.0007631305487760028,
#  'nginx': 6.619638604929675e-08,
#  'uwsgi': 0.028065124851720098,
#  'animated-gif': 0.4093,
#  'makefile': 0.572413178707047,
#  'elixir': 5.72018599424861e-13,
#  'sockets': 0.44914981358345263,
#  'mysql': 4.1241956039020325e-48,
#  'vb': 2.2059624244055062e-18,
#  'xcode': 1.1947713794892725e-17,
#  'interface': 0.5807932479912283,
#  'code-generation': 0.1900789948728397,
#  'mongodb-java': 0.16752649,
#  'android-layout': 0.12218535983399638,
#  'android-studio': 0.00505891661603982,
#  'android-spinner': 0.5408055756991601,
#  'uitableview': 0.21251007358034013,
#  'typescript': 3.357428205827674e-83,
#  'gulp': 7.852670463220621e-05,
#  'angular': 3.772460933625095e-135,
#  'ram': 0.634557714714,
#  'templates': 0.3798264896339518,
#  'constants': 0.16051654845657343,
#  'docker': 5.481695111060806e-84,
#  'kitematic': 0.4093,
#  'python': 9.556114369952005e-05,
#  'python-2': 0.46976710602803107,
#  'visualvm': 0.4093,
#  'oraclejdk': 0.4093,
#  'php': 1.76671788279247e-114,
#  'opengl': 0.010668630913435919,
#  'glut': 0.34892649,
#  'glew': 0.5907,
#  'imageview': 0.21909680110691024,
#  'matlab': 1.8048283569066184e-10,
#  'double': 0.0018046943151491842,
#  'precision': 0.5408055756991601,
#  'writefile': 0.34892649,
#  'python-3': 0.009198330705616879,
#  'gradle': 1.5334674977587548e-20,
#  'serial-port': 0.34892649,
#  'android-volley': 0.30799460719755695,
#  'bash': 0.09173621742125491,
#  'shell': 0.018816795461657876,
#  'playframework': 0.19230405691058897,
#  'sbt': 0.00032238564964342137,
#  'webpack': 1.932000845775091e-40,
#  'jekyll': 0.009881530212648783,
#  'liquid': 0.3336313844050527,
#  'printing': 0.41200608621188567,
#  'r': 1.0615562410174712e-07,
#  'statistics': 0.14842984379725824,
#  'opencv': 0.0012317081658651966,
#  'node': 2.77626399741293e-55,
#  'polymer-1': 0.65107351,
#  'node-gyp': 0.068568592357,
#  'npm-install': 2.210553019214638e-05,
#  'ecto': 0.011487055601809036,
#  'abstract-syntax-tree': 0.365442285286,
#  'angularjs': 0.004561251750775021,
#  'restore': 0.1900789948728397,
#  'compose': 0.4093,
#  'naming': 0.65107351,
#  'django': 6.4170000305224935e-12,
#  'static-site': 0.4093,
#  'django-commands': 0.4093,
#  'ecmascript-6': 3.58198894229372e-27,
#  'codenameone': 0.206110877643,
#  'soap': 0.399818209574014,
#  'hadoop': 0.016226291779613558,
#  'hdfs': 0.004701651857820438,
#  'gzip': 0.4749587118995165,
#  'email': 0.2510892694433204,
#  'reactjs': 7.075294262184287e-111,
#  'while-loop': 3.525031354867351e-05,
#  'primitive-types': 0.65107351,
#  'cmake': 1.4946004445949411e-05,
#  'onload': 0.65107351,
#  'asp': 1.1972348666010613e-18,
#  'visual-studio': 0.00010218649083722239,
#  'visual-studio-2015': 2.6695046254712786e-08,
#  'unity3d': 0.0019910236302650634,
#  'textures': 0.4093,
#  'sprite': 0.65107351,
#  'unity5': 0.2962612280941942,
#  'postgresql': 1.6146729247147783e-07,
#  'arraylist': 2.350160654432773e-10,
#  'android-listview': 0.5907,
#  'android-adapter': 0.3210782967714346,
#  'function': 8.889169760083272e-15,
#  'validation': 0.4914431276609235,
#  'date': 0.0001199310769348416,
#  'try-except': 0.5907,
#  'vim': 0.03749099644008982,
#  'express': 1.4817240844439312e-09,
#  'escaping': 0.09437740185136434,
#  'loops': 1.1137374669514303e-12,
#  'for-loop': 3.142143327429653e-12,
#  'printf': 0.0018046943151491842,
#  'line': 0.4591944243008399,
#  'redux': 5.486003525113737e-31,
#  't4': 0.4093,
#  'entity-framework-core': 2.9168787878018293e-09,
#  'cordova': 0.0017212730595021221,
#  'ide': 0.00483235419753174,
#  'webstorm': 0.011487055601809036,
#  'tslint': 0.004701651857820438,
#  'cluster-analysis': 0.6663686155949473,
#  'dbscan': 0.4093,
#  'facebook': 0.012291182293314168,
#  'facebook-graph-api': 0.43804787671100237,
#  'parse-platform': 0.2962612280941942,
#  'shuffle': 0.34892649,
#  'laravel-5': 3.316148196035748e-26,
#  'cors': 9.047793507645515e-06,
#  'ng-file-upload': 0.4093,
#  'android-viewpager': 0.6663686155949473,
#  'debugging': 0.125134248598129,
#  'web': 0.007436521014676413,
#  'ffmpeg': 0.0007804283650498608,
#  'alexa-skills-kit': 0.65107351,
#  'entity-framework': 3.462401110442647e-05,
#  'security': 0.037730171070538505,
#  'backend': 0.6663686155949473,
#  'android-annotations': 0.16752649,
#  'foreign-keys': 0.04541407432175203,
#  'foreign-key-relationship': 0.4093,
#  'pgadmin': 0.65107351,
#  'es6-shim': 0.4093,
#  'casting': 0.1751412608576502,
#  'boolean': 0.1527561368016906,
#  'nullable': 0.068568592357,
#  'regex': 1.5015470959473308e-36,
#  'pandas': 4.4335178095240015e-31,
#  'cakephp': 0.15201958617739292,
#  'lamp': 0.34892649,
#  'cakephp-3': 0.6663686155949473,
#  'calendar': 0.20608162214401213,
#  'sublimetext2': 0.34892649,
#  'color-scheme': 0.5907,
#  'spring': 5.374587932504976e-19,
#  'spring-mvc': 0.000671020187806324,
#  'logcat': 0.004701651857820438,
#  'android-logcat': 0.1900789948728397,
#  'shake-build-system': 0.4093,
#  'ssl': 2.850223274252391e-08,
#  'ssl-certificate': 0.00032238564964342137,
#  'saml': 0.4093,
#  'saml-2': 0.16752649,
#  'firefox': 0.10284007878206684,
#  'browser': 0.2863005795606521,
#  'indexing': 0.41675488319515586,
#  'undefined': 0.6001817904259861,
#  'yii': 0.4591944243008399,
#  'titan': 0.4093,
#  'gremlin': 0.4093,
#  'tinkerpop3': 0.4093,
#  'append': 0.21469974948068807,
#  'reshape': 0.5250412881004836,
#  'dataformat': 0.4093,
#  'docker-compose': 1.5055230387339202e-21,
#  'provisioning-profile': 0.09437740185136434,
#  'enterprise': 0.634557714714,
#  'enterprise-distribution': 0.4093,
#  'minecraft': 0.02509393657655089,
#  'bukkit': 0.34892649,
#  'wordpress': 1.0936485206499005e-11,
#  'themes': 0.30799460719755695,
#  'if-statement': 6.1758681493920545e-18,
#  'git': 2.3442700734398283e-41,
#  'google-maps': 0.45474156914976627,
#  'google-maps-api-3': 0.3596956015674112,
#  'yahoo-finance': 0.4093,
#  'sass': 0.00010942237053414294,
#  'compass': 0.5907,
#  'swift2': 0.23311955929629896,
#  'realm': 2.8038415590115855e-06,
#  'ssh': 0.04051893690766142,
#  'certificate': 0.16752649,
#  'rsa': 0.1900789948728397,
#  'modulus': 0.2962612280941942,
#  'pymongo': 0.1900789948728397,
#  'delphi': 0.0034746071209716812,
#  'draw': 0.65107351,
#  'delphi-10-seattle': 0.04248169388276772,
#  'tcanvas': 0.5907,
#  'google-cloud-platform': 1.1938784878472886e-09,
#  'android-number-picker': 0.4093,
#  'slick': 0.09437740185136434,
#  'npm': 1.0702867716581963e-29,
#  'bower': 0.028065124851720098,
#  'ruby': 1.3201865422636538e-08,
#  'syntax-error': 0.0001516229512428266,
#  'apache-spark': 8.907317188852182e-18,
#  'babeljs': 1.4989265458576344e-06,
#  'commonjs': 0.028065124851720098,
#  'sqlite': 0.0011069933933354611,
#  'comparable': 0.634557714714,
#  'testing': 0.0006205811888916017,
#  'architecture': 0.41200608621188567,
#  'devops': 0.011487055601809036,
#  'variables': 6.270729718611479e-07,
#  'sql': 4.657364355781401e-58,
#  'web-application-firewall': 0.5907,
#  'actionscript-3': 0.008755939209938519,
#  'flash': 0.008755939209938519,
#  'telerik': 0.365442285286,
#  'updatepanel': 0.4093,
#  'json': 0.0006526036310163012,
#  'jackson': 0.0007876512329426371,
#  'apache': 0.39417502873260823,
#  'mod-rewrite': 0.07191754508679146,
#  'http-referer': 0.5907,
#  'class': 5.020007984045841e-05,
#  'angular2-forms': 6.699394212464064e-07,
#  'kubernetes': 3.48239883641468e-18,
#  'windows-7-x64': 0.4093,
#  'unit-testing': 1.288432094022823e-16,
#  'mstest': 0.4093,
#  'assert': 0.3336313844050527,
#  'xunit': 0.004701651857820438,
#  'assertion': 0.4093,
#  'undefined-index': 0.5907,
#  'swing': 1.61061101581918e-08,
#  'jtextfield': 0.206110877643,
#  'numberformatexception': 0.5907,
#  'iphone': 0.26198267602275044,
#  'air': 0.5907,
#  'dns': 0.06709795878361238,
#  'cname': 0.4093,
#  'indentation': 0.3336313844050527,
#  'relational-database': 0.5907,
#  'entity-relationship-model': 0.5907,
#  'dictionary': 8.998445929212048e-06,
#  'android-fragments': 0.1053055429814512,
#  'chrome-custom-tabs': 0.028065124851720098,
#  'iterable': 0.068568592357,
#  'string': 7.935022155604084e-39,
#  'windows': 0.34212720798451884,
#  'google-chrome': 4.597617532034739e-12,
#  'google-chrome-extension': 0.02659500540178239,
#  'vue': 3.9730463055968193e-38,
#  'webpack-style-loader': 0.068568592357,
#  'char': 0.0001516229512428266,
#  'alphabet': 0.34892649,
#  'sizeof': 0.14680823772006868,
#  'strlen': 0.5907,
#  'gameplay-kit': 0.4093,
#  'gkminmaxstrategist': 0.4093,
#  'parameter-passing': 0.14680823772006868,
#  'pass-by-reference': 0.4593841853212062,
#  'telegram': 0.0007876512329426371,
#  'github': 9.016635426489792e-13,
#  'qt': 0.22795025787288462,
#  'image-processing': 0.2601254396646332,
#  'computer-vision': 0.028682670309242264,
#  'laravel': 1.9468947533753389e-28,
#  'collections': 0.4465760076622365,
#  'sql-server': 1.710030007816609e-28,
#  'ms-access-2010': 0.34892649,
#  'web-services': 0.1380486161504937,
#  'wsdl': 0.34892649,
#  'hash': 0.006664665330949821,
#  'dig': 0.4093,
#  'ruby-2': 0.1900789948728397,
#  'safe-navigation-operator': 0.4093,
#  'command-line': 0.4928696170294881,
#  'text-files': 0.04101019247758906,
#  'streamreader': 0.5907,
#  'macos': 3.707337997893852e-13,
#  'null-terminated': 0.4093,
#  'elasticsearch': 1.1940272432175804e-11,
#  'avfoundation': 0.021365246372307637,
#  'segue': 0.5408055756991601,
#  'algorithm': 7.52820095622153e-14,
#  'xcode7': 0.16051654845657343,
#  'code-coverage': 0.04541407432175203,
#  'monads': 0.365442285286,
#  'editor': 0.4749587118995165,
#  'sublimetext3': 0.014381035656205793,
#  'atom-editor': 0.062000170674415524,
#  'phoenix-framework': 2.210553019214638e-05,
#  'redbean': 0.4093,
#  'flexbox': 0.014381035656205793,
#  'scikit-learn': 6.674412301298387e-08,
#  'random-forest': 0.1900789948728397,
#  'grid-search': 0.16752649,
#  'go': 3.7795774975331295e-11,
#  'deferred': 0.4093,
#  'internet-explorer-9': 0.34892649,
#  'websocket': 0.0003043989807704624,
#  'java-websocket': 0.4093,
#  'stl': 0.5310963706993294,
#  'hashmap': 0.0237207391005397,
#  'key-value': 0.634557714714,
#  'picasso': 0.4093,
#  'notifications': 0.03749099644008982,
#  'taskstackbuilder': 0.4093,
#  'aws-lambda': 5.613201010399061e-12,
#  'database': 5.032836969390694e-07,
#  'oracle': 6.269853656485139e-18,
#  'oracle11g': 0.0016586297579977666,
#  'pillow': 0.16752649,
#  'encryption': 0.002004930360949104,
#  'py2exe': 0.4093,
#  'relative-import': 0.4093,
#  'logging': 6.321552998205766e-11,
#  'output': 0.004238044985201143,
#  'pycharm': 1.4679258678606072e-05,
#  'remote-debugging': 0.4093,
#  'jquery-plugins': 0.65107351,
#  'android-actionbar': 0.30799460719755695,
#  'android-toolbar': 0.65107351,
#  'iis': 7.901970177955859e-05,
#  'autostart': 0.16752649,
#  'hyperlink': 0.14842984379725824,
#  'outline': 0.16752649,
#  'mysqli': 3.701251043928491e-12,
#  'http': 2.6609305708768516e-07,
#  'curl': 0.054244629493126695,
#  'static': 0.23898120917760637,
#  'global': 0.09699057426202683,
#  'smartface': 0.5907,
#  'composer-php': 0.0005884709064815834,
#  'gitk': 0.4093,
#  'ssh-agent': 0.4093,
#  'docker-machine': 2.210553019214638e-05,
#  'syntax': 0.025141917206355335,
#  'ios9': 0.003219171503750022,
#  'code-signing': 0.028065124851720098,
#  'datetime': 0.15833455249022224,
#  'filter': 0.2747231101666367,
#  'transform': 0.5408055756991601,
#  'edge-detection': 0.5907,
#  'frameworks': 0.2674184312125307,
#  'release': 0.028065124851720098,
#  'android-emulator': 0.055816394851284194,
#  'http-proxy': 0.028065124851720098,
#  'phantomjs': 0.1900789948728397,
#  'angular2-routing': 5.833940538446355e-19,
#  'android-espresso': 5.4008136311132136e-05,
#  'android-multidex': 0.16752649,
#  'rest': 0.0014229222133497342,
#  'rest-assured': 0.011487055601809036,
#  'mockmvc': 0.028065124851720098,
#  'restfuse': 0.4093,
#  'redirect': 0.5113381736833689,
#  'url-redirection': 0.3210782967714346,
#  'xml': 2.2096372290141254e-06,
#  'resttemplate': 0.068568592357,
#  'audio': 0.4192067520087716,
#  'html5-audio': 0.16752649,
#  'machine-learning': 0.030528281415116786,
#  'servlet-3': 0.34892649,
#  'get-method': 0.5907,
#  'clang': 0.00040493680361997547,
#  'clion': 0.04541407432175203,
#  'clang-format': 0.068568592357,
#  'android-intent': 0.5310963706993294,
#  'objective-c': 0.001466031506993935,
#  'uisearchbar': 0.6663686155949473,
#  'linear-regression': 0.028065124851720098,
#  'virtualenv': 0.00013195244639905237,
#  'pytest': 3.7032618826793088e-06,
#  'test-coverage': 0.4093,
#  'angular-ui-modal': 0.4093,
#  'apt-get': 0.16752649,
#  'webpack-dev-server': 1.5157450885806411e-06,
#  'react-hot-loader': 0.4093,
#  'cookie-session': 0.4093,
#  'traversal': 0.34892649,
#  'functor': 0.65107351,
#  'haskell-lens': 0.5907,
#  'duplicates': 0.1527561368016906,
#  'row': 0.04248169388276772,
#  'polymer': 0.3336313844050527,
#  'error-handling': 0.039911960945649604,
#  'runtime-error': 0.206110877643,
#  'select': 0.006664665330949821,
#  'mobile-safari': 0.09437740185136434,
#  'multi-select': 0.4093,
#  'cloud9-ide': 0.5907,
#  'semantic-ui': 0.1900789948728397,
#  'kibana': 0.068568592357,
#  'django-rest-framework': 1.1938784878472886e-09,
#  'unique': 0.399818209574014,
#  'protractor': 0.1103943251555028,
#  'android-camera2': 0.16752649,
#  'perl': 2.7622837924573915e-13,
#  'dom-events': 0.1217496954237201,
#  'addeventlistener': 0.65107351,
#  'event-listener': 0.5907,
#  'd3': 0.2220186584381035,
#  'charts': 0.4928696170294881,
#  'weather': 0.34892649,
#  'sequelize': 2.539274544246539e-07,
#  'ns-3': 0.206110877643,
#  'ndnsim': 0.5907,
#  'openshift': 0.068568592357,
#  'async-await': 0.00010942237053414294,
#  'win-universal-app': 0.0019243861054059055,
#  'uwp': 0.06780908789854784,
#  'yarn': 0.04541407432175203,
#  'hadoop2': 0.634557714714,
#  'emr': 0.0019243861054059055,
#  'elastic-map-reduce': 0.4093,
#  'lazy-loading': 0.068568592357,
#  'static-members': 0.16752649,
#  'stdmap': 0.206110877643,
#  'std-pair': 0.34892649,
#  'stdarray': 0.5907,
#  'phar': 0.4093,
#  'php-ini': 0.4093,
#  'sorting': 7.156649763337048e-11,
#  'mergesort': 0.1217496954237201,
#  'insertion-sort': 0.5907,
#  'selection-sort': 0.34892649,
#  'magento2': 0.4093,
#  'magento-2': 0.4093,
#  'linq': 1.0141022321935394e-06,
#  'linq-to-sql': 0.07191754508679146,
#  'promise': 1.0176901827883813e-10,
#  'app-store': 0.4593841853212062,
#  'watchos-2': 0.634557714714,
#  'azure': 2.7606379330035923e-08,
#  'virtual-machine': 0.11120178933868524,
#  'ping': 0.65107351,
#  'icmp': 0.5907,
#  'flask': 0.0007883487774383272,
#  'flask-sqlalchemy': 0.004509775899336363,
#  'flask-restful': 0.16752649,
#  'wp-api': 0.4093,
#  'wordpress-rest-api': 0.4093,
#  'generics': 0.003643040702776224,
#  'types': 0.0013933413626630935,
#  'pagination': 0.011487055601809036,
#  'javacv': 0.5907,
#  'openni': 0.5907,
#  'lets-encrypt': 0.028065124851720098,
#  'neural-network': 2.3531610007387603e-06,
#  'keras': 9.604978350657154e-17,
#  'data-science': 0.6001817904259861,
#  'batch-file': 3.445236539477137e-12,
#  'cmd': 0.008146802793637175,
#  'system': 0.25067935251015555,
#  'reactive-programming': 0.00013195244639905237,
#  'rx-java': 7.416211085563845e-09,
#  'reactivex': 0.068568592357,
#  'groovy': 0.000912206767423078,
#  'undefined-behavior': 0.19230405691058897,
#  'unions': 0.1900789948728397,
#  'list': 3.197063889179381e-11,
#  'jvm': 0.18220935382679682,
#  'dataframe': 0.011217571005606934,
#  'phabricator': 0.4093,
#  'arcanist': 0.4093,
#  'jelastic': 0.4093,
#  'ruby-on-rails-5': 0.00017000594487883935,
#  'actioncable': 0.028065124851720098,
#  'symfony': 0.12899407921338815,
#  'propel': 0.5907,
#  'excel': 6.705274077869741e-23,
#  'pm2': 0.0019243861054059055,
#  'jenkins-workflow': 0.011487055601809036,
#  'phpmyadmin': 0.0026820210062485244,
#  'psycopg2': 0.09437740185136434,
#  'uitest': 0.4093,
#  'forms': 0.007384085751009041,
#  'redux-form': 0.00032238564964342137,
#  'testcase': 0.5907,
#  'amazon-dynamodb': 0.0009113955472782547,
#  'google-signin': 0.0007876512329426371,
#  'googlesigninaccount': 0.4093,
#  'addition': 0.65107351,
#  'tensorflow': 7.414934031009736e-43,
#  'csv': 2.12361054024365e-05,
#  'merge': 0.056060146087570706,
#  'numbers': 0.039494441573228976,
#  'java-8': 0.000671020187806324,
#  'subset': 0.1217496954237201,
#  'file-handling': 0.04248169388276772,
#  'adblock': 0.65107351,
#  'struct': 0.30589581652525916,
#  'binaryfiles': 0.4591944243008399,
#  'cross-browser': 0.5907,
#  'callback': 0.0180620708868228,
#  'graphics': 0.07191754508679146,
#  'session': 0.007394432191709546,
#  'file': 7.99417921554212e-09,
#  'mobile': 0.32840035416671465,
#  'nodes': 0.206110877643,
#  'uniq': 0.5907,
#  'icons': 0.5250412881004836,
#  'contacts': 0.634557714714,
#  'oop': 0.0012511677711895576,
#  'fpga': 0.34892649,
#  'as': 0.34892649,
#  'kernel': 0.5408055756991601,
#  'rubygems': 0.5907,
#  'bson': 0.5907,
#  'autohotkey': 0.634557714714,
#  'percentage': 0.1217496954237201,
#  'angularjs-directive': 0.634557714714,
#  'angularjs-scope': 0.65107351,
#  'scanf': 0.010668630913435919,
#  'wpf': 0.0017897887961042995,
#  'listbox': 0.07191754508679146,
#  'comments': 0.1900789948728397,
#  'android-sqlite': 1.923863572067544e-06,
#  'intellij-idea': 2.459193396552265e-20,
#  'fonts': 0.45313810075934463,
#  'typeface': 0.5907,
#  'jetbrains-ide': 0.365442285286,
#  'matrix': 0.0020452956481417654,
#  'redefinition': 0.5907,
#  'networking': 0.3646296184504848,
#  'routing': 0.10553614419536297,
#  'ip': 0.006738287559617262,
#  'mikrotik': 0.5907,
#  'listview': 0.000328666912515052,
#  'ienumerable': 0.4591944243008399,
#  'jira': 0.206110877643,
#  'linked-list': 2.160979757324869e-05,
#  'sshd': 0.65107351,
#  'internet-explorer': 0.25067935251015555,
#  'selenium': 0.21733629992428077,
#  'twig': 0.427586821292953,
#  'random': 9.628300965409299e-07,
#  'lan': 0.34892649,
#  'subnet': 0.34892649,
#  'joomla': 0.1217496954237201,
#  'external': 0.65107351,
#  'eigen': 0.65107351,
#  'libgdx': 0.5250412881004836,
#  'load': 0.634557714714,
#  'jasmine': 5.199739889847438e-07,
#  'automated-tests': 0.055816394851284194,
#  'jasmine2': 0.4093,
#  'webview': 0.0012143211948111743,
#  'progress-bar': 0.09437740185136434,
#  'xamarin': 4.089941898923583e-15,
#  'progress': 0.65107351,
#  'simple-injector': 0.4093,
#  'hyper-v': 0.011487055601809036,
#  'git-commit': 0.16752649,
#  'compound-assignment': 0.5907,
#  'ajax': 3.4654481397563025e-09,
#  'routes': 0.0180620708868228,
#  'spark-java': 0.4093,
#  'spark-framework': 0.4093,
#  'data': 0.11008384393536809,
#  'gunicorn': 0.028065124851720098,
#  'afnetworking': 0.365442285286,
#  'nsurlsession': 0.1900789948728397,
#  'spring-boot': 4.2679432653151875e-26,
#  'dom': 0.4892395025448966,
#  'tree': 0.2558065312752091,
#  'instructions': 0.5907,
#  'heap': 0.5250412881004836,
#  'yield': 0.028065124851720098,
#  'customization': 0.16752649,
#  'facebook-login': 0.4093,
#  'facebook-ios-sdk': 0.16752649,
#  'apache-zeppelin': 0.16752649,
#  'sql-server-2008-r2': 0.014822988335768611,
#  'drop-down-menu': 0.3210782967714346,
#  'pageload': 0.65107351,
#  'android-coordinatorlayout': 0.16752649,
#  'android-appbarlayout': 0.4093,
#  'custom-scrolling': 0.4093,
#  'jenkins': 2.684286439401542e-22,
#  'jenkins-plugins': 0.0007876512329426371,
#  'webhooks': 0.16752649,
#  'facebook-public-feed-api': 0.4093,
#  'twitter': 0.3903918052945073,
#  'netbeans': 0.005172133291310683,
#  'configuration': 9.047793507645515e-06,
#  'lint': 0.00032238564964342137,
#  'eslint': 2.297483173556336e-12,
#  'visual-c': 0.0792939980084512,
#  'fbsdk': 0.16752649,
#  'iframe': 0.062000170674415524,
#  'date-formatting': 0.1217496954237201,
#  'dll': 0.4571676122975578,
#  'throw': 0.4093,
#  'windows-runtime': 0.16752649,
#  'nix': 0.16752649,
#  'nixos': 0.4093,
#  'nixpkgs': 0.4093,
#  'command-prompt': 0.6663686155949473,
#  'pyspark': 1.474606366062197e-11,
#  'design-patterns': 0.4187276611740842,
#  'android-service': 0.09437740185136434,
#  'mvp': 0.011487055601809036,
#  'android-googleapiclient': 0.4093,
#  'sqlalchemy': 1.4946004445949411e-05,
#  'rx-swift': 0.0019243861054059055,
#  'sql-server-2005': 0.65107351,
#  'performance': 0.37395480103601647,
#  'angular-ui-bootstrap': 0.4749587118995165,
#  'dynamic': 0.20608162214401213,
#  'malloc': 0.0030551791351772204,
#  'realloc': 0.206110877643,
#  'post': 0.41675488319515586,
#  'retrofit': 0.0070982846708829385,
#  'retrofit2': 0.0009113955472782547,
#  'ruby-on-rails': 0.011971758658568692,
#  'ruby-on-rails-4': 0.33354571816854856,
#  'converter': 0.21909680110691024,
#  'weka': 0.5907,
#  'text-mining': 0.206110877643,
#  'text-classification': 0.34892649,
#  'arff': 0.5907,
#  'service': 0.6096081947054928,
#  'virtualbox': 0.0020362844788427426,
#  'producer-consumer': 0.5907,
#  'critical-section': 0.5907,
#  'replace': 0.0237207391005397,
#  'preg-replace': 0.02509393657655089,
#  'react-jsx': 3.7032618826793088e-06,
#  'installation': 0.025821366843633228,
#  'anaconda': 7.660220643109638e-12,
#  'free': 0.34892649,
#  'android-activity': 0.014248019641050118,
#  'backbone': 0.399818209574014,
#  'nsattributedstring': 0.5408055756991601,
#  'sdl': 0.206110877643,
#  'fatal-error': 0.4591944243008399,
#  'automation': 0.15201958617739292,
#  'authentication': 1.3645432506976636e-06,
#  'oauth': 0.00040493680361997547,
#  'oauth-2': 0.00040493680361997547,
#  'access-token': 0.028065124851720098,
#  'jwt': 7.126505711707376e-09,
#  'safari': 0.03749099644008982,
#  'pyodbc': 0.16752649,
#  'unixodbc': 0.4093,
#  'asp-classic': 0.206110877643,
#  'categorical-data': 0.65107351,
#  'amazon-cognito': 5.4008136311132136e-05,
#  'aws-api-gateway': 1.5157450885806411e-06,
#  'pdo': 0.0011819034455434337,
#  'logstash': 0.068568592357,
#  'export-to-csv': 0.1900789948728397,
#  'kibana-4': 0.4093,
#  'deployment': 0.006112562848705252,
#  'assembly': 0.011062184244303441,
#  'x86': 0.30172485883085887,
#  'compiler-optimization': 0.004701651857820438,
#  'nan': 0.5250412881004836,
#  'ocaml': 0.21909680110691024,
#  'entity-framework-6': 0.10553614419536297,
#  'http-status-code-404': 0.19230405691058897,
#  'http-status-codes': 0.4093,
#  'ascii': 0.09699057426202683,
#  'console-application': 0.2962612280941942,
#  'analysis': 0.34892649,
#  'nfs': 0.16752649,
#  'qnap': 0.4093,
#  'xamarin-forms': 0.16752649,
#  'visual-studio-emulator': 0.4093,
#  'memory': 0.32840035416671465,
#  'derived-class': 0.634557714714,
#  'pylint': 0.0019243861054059055,
#  'portable-class-library': 0.4093,
#  'submit': 0.206110877643,
#  'yesod': 0.4093,
#  'hamlet': 0.4093,
#  'shakespeare-text': 0.4093,
#  'core-graphics': 0.365442285286,
#  'type-conversion': 0.056248716078848834,
#  'countdown': 0.1217496954237201,
#  'video': 0.2829744890423591,
#  'video-streaming': 0.1900789948728397,
#  'html5-video': 0.3336313844050527,
#  'ansible': 1.1938784878472886e-09,
#  'ansible-playbook': 0.0007876512329426371,
#  'webforms': 0.4749587118995165,
#  'dependencies': 0.0001787983704061568,
#  'repository': 0.1900789948728397,
#  'singly-linked-list': 0.34892649,
#  'lambda': 0.027356941971097438,
#  'fluent': 0.4093,
#  'accessibility': 0.011487055601809036,
#  'in-app-purchase': 0.04541407432175203,
#  'uicollectionviewcell': 0.068568592357,
#  'uistackview': 0.028065124851720098,
#  'gcc': 0.07974485180097167,
#  'address-sanitizer': 0.4093,
#  'android-gradle-plugin': 1.7334540861537364e-07,
#  'google-play-services': 0.009881530212648783,
#  'checkbox': 0.0029531437838587683,
#  'radio-button': 0.1217496954237201,
#  'plugins': 0.055816394851284194,
#  'uiwebview': 0.1900789948728397,
#  'wkwebview': 0.011487055601809036,
#  'applinks': 0.4093,
#  'sfsafariviewcontroller': 0.068568592357,
#  'mocking': 3.7032618826793088e-06,
#  'e2e-testing': 0.4093,
#  'tsql': 8.700207885555996e-10,
#  'tsql-sequence': 0.5907,
#  'global-variables': 0.06335938134240936,
#  'environment-variables': 0.00040493680361997547,
#  'packages': 0.3210782967714346,
#  'environment': 0.028065124851720098,
#  'ipython': 0.0012143211948111743,
#  'rdd': 0.5408055756991601,
#  'unityscript': 0.07191754508679146,
#  'servlets': 0.012983152066498922,
#  'jakarta-ee': 0.41200608621188567,
#  'jax-rs': 0.1900789948728397,
#  'jax-ws': 0.5907,
#  'junit': 0.003643040702776224,
#  'caching': 0.00014026602605286953,
#  'asynchronous': 1.0309214423440404e-06,
#  'this': 0.30799460719755695,
#  'heatmap': 0.4093,
#  'seaborn': 0.004509775899336363,
#  'gitlab': 1.4989265458576344e-06,
#  'gitlab-ci': 2.539274544246539e-07,
#  'gitlab-ci-runner': 5.4008136311132136e-05,
#  'gruntjs': 0.04541407432175203,
#  'underscore': 0.19230405691058897,
#  'git-clone': 0.16752649,
#  'isomorphic-javascript': 0.16752649,
#  'threadpool': 0.65107351,
#  'express-session': 0.4093,
#  'connect-mongo': 0.4093,
#  'ms-access': 1.5801793715967883e-05,
#  'memory-management': 0.5807932479912283,
#  'uiimage': 0.3903918052945073,
#  'data-binding': 0.014403741581310844,
#  'svg': 0.0025130681365072315,
#  'png': 0.3210782967714346,
#  'render': 0.65107351,
#  'launching': 0.4093,
#  'login': 0.04101019247758906,
#  'jgit': 0.4093,
#  'git-blame': 0.16752649,
#  'pinvoke': 0.34892649,
#  'okhttp3': 0.021365246372307637,
#  'cluster-computing': 0.365442285286,
#  'slurm': 0.028065124851720098,
#  'virtual-functions': 0.65107351,
#  'constexpr': 0.04541407432175203,
#  'relayjs': 0.4093,
#  'graphql': 7.126505711707376e-09,
#  'electron': 2.8038415590115855e-06,
#  'unix-socket': 0.4093,
#  'switch-statement': 0.05059085898675897,
#  'publishing': 0.1900789948728397,
#  'github-pages': 0.3336313844050527,
#  'lektor': 0.5907,
#  'web-scraping': 0.0792939980084512,
#  'rvest': 0.3336313844050527,
#  'reshape2': 0.634557714714,
#  'api': 0.0020353298058433623,
#  'android-api-levels': 0.5907,
#  'time': 0.0075796592182131375,
#  'nsdate': 0.15201958617739292,
#  'nsuserdefaults': 0.3210782967714346,
#  'winforms': 2.196852617526171e-15,
#  'data-mining': 0.5907,
#  'django-queryset': 0.068568592357,
#  'azure-web-sites': 0.0070982846708829385,
#  'android-glide': 0.011487055601809036,
#  'find': 0.3210782967714346,
#  'active-directory': 0.09437740185136434,
#  'ldap': 0.011487055601809036,
#  'code-snippets': 0.65107351,
#  'procedural': 0.5907,
#  'cookies': 0.024678760695360204,
#  'proxy': 1.635994991322708e-05,
#  'stream': 0.04541407432175203,
#  'markdown': 0.00017000594487883935,
#  'ranking': 0.34892649,
#  'python-requests': 0.00040493680361997547,
#  'urllib3': 0.4093,
#  'applicative': 0.4093,
#  'comonad': 0.4093,
#  'spring-data': 0.0001787983704061568,
#  'spring-data-mongodb': 0.16752649,
#  'spring-data-commons': 0.4093,
#  'spring-cloud': 0.09437740185136434,
#  'netflix': 0.5907,
#  'object-create': 0.4093,
#  'match': 0.02509393657655089,
#  'momentjs': 7.84120380651313e-05,
#  'slim': 0.365442285286,
#  'slim-3': 0.4093,
#  'uicolor': 0.206110877643,
#  'cgpoint': 0.5907,
#  'css-transitions': 0.365442285286,
#  'grayscale': 0.4093,
#  'flux': 0.028065124851720098,
#  'xmpp': 0.07191754508679146,
#  'xmpphp': 0.5907,
#  'prosody-im': 0.5907,
#  'spring-data-rest': 0.0019243861054059055,
#  'json-patch': 0.4093,
#  'copying': 0.5907,
#  'apache-kafka': 5.678957555020259e-10,
#  'kafka-consumer-api': 0.00032238564964342137,
#  'uiimageview': 0.14680823772006868,
#  'fgets': 0.1217496954237201,
#  'isinstance': 0.4093,
#  'push-notification': 0.16051654845657343,
#  'nuget': 5.199739889847438e-07,
#  'tag-helpers': 0.068568592357,
#  'math': 9.436190200586236e-09,
#  'expression': 0.14680823772006868,
#  'tuples': 0.4571676122975578,
#  'android-recyclerview': 0.0005099144510397637,
#  'compilation': 0.2558065312752091,
#  'methods': 2.2293329831200853e-07,
#  'adb': 0.18840239310216114,
#  'substr': 0.206110877643,
#  'web-worker': 0.1900789948728397,
#  'search': 0.00860838825548205,
#  'nullpointerexception': 9.334119548022229e-06,
#  'appbar': 0.5907,
#  'primes': 0.34892649,
#  'palindrome': 0.1217496954237201,
#  'mean': 0.04248169388276772,
#  'macros': 0.004238044985201143,
#  'sparql': 0.206110877643,
#  'rdf': 0.34892649,
#  'semantic-web': 0.5907,
#  'numpy': 6.68508367120778e-11,
#  'sha256': 0.4093,
#  'hmac': 0.65107351,
#  'filewriter': 0.5907,
#  'leaflet': 0.0007804283650498608,
#  'implicit-cast': 0.65107351,
#  'cassandra': 0.11120178933868524,
#  'nodetool': 0.4093,
#  'emacs': 0.1900789948728397,
#  'spacemacs': 0.16752649,
#  'airflow': 2.210553019214638e-05,
#  'graph-algorithm': 0.34892649,
#  'git-push': 0.5907,
#  'debian': 0.427586821292953,
#  'dockerfile': 1.5753518717465105e-13,
#  'sprite-kit': 0.30799460719755695,
#  'universal': 0.4093,
#  'apple-push-notifications': 0.0180620708868228,
#  'voip': 0.5408055756991601,
#  'pushkit': 0.4093,
#  'service-worker': 2.539274544246539e-07,
#  'progressive-web-apps': 0.004701651857820438,
#  'saas': 0.16752649,
#  'code-reuse': 0.4093,
#  'reusability': 0.16752649,
#  'azure-diagnostics': 0.4093,
#  'xpath': 0.03425069103634785,
#  'recursion': 4.1434023485071225e-05,
#  'pom': 0.1900789948728397,
#  'aar': 0.068568592357,
#  'hibernate': 0.0007883487774383272,
#  'vba': 8.234321550548812e-20,
#  'tcp': 0.055816394851284194,
#  'bower-install': 0.4093,
#  'build': 9.100805042572962e-07,
#  'reporting-services': 0.16781298685176207,
#  'reportviewer': 0.16752649,
#  'microsoft-reporting': 0.4093,
#  'google-play': 0.06733032888330838,
#  'developer-console': 0.16752649,
#  'foreach': 0.31077823910287294,
#  'spark-streaming': 0.04541407432175203,
#  'amazon-kinesis': 0.068568592357,
#  'checkpointing': 0.4093,
#  'xampp': 0.21909680110691024,
#  'savefiledialog': 0.5907,
#  'counter': 0.06335938134240936,
#  'amazon-s3': 6.820676416787515e-14,
#  'amazon-cloudfront': 0.068568592357,
#  'migrate': 0.16752649,
#  'makemigrations': 0.4093,
#  'sketchflow': 0.4093,
#  'combinatorics': 0.07191754508679146,
#  'lapply': 0.5907,
#  'sapply': 0.5907,
#  'okhttp': 0.009881530212648783,
#  'android-networking': 0.5408055756991601,
#  'androidhttpclient': 0.65107351,
#  'wampserver': 0.3210782967714346,
#  'forum': 0.206110877643,
#  'null': 0.21469974948068807,
#  'return': 0.008830645436785961,
#  'react-router': 9.403598629366081e-13,
#  'crashlytics': 0.028065124851720098,
#  'xaml': 0.06733032888330838,
#  'wpf-controls': 0.5408055756991601,
#  'alamofire': 0.039911960945649604,
#  'temp-tables': 0.4093,
#  'element': 0.634557714714,
#  'migration': 0.11008384393536809,
#  'data-migration': 0.4093,
#  'data-management': 0.4093,
#  'rtf': 0.634557714714,
#  'git-lfs': 0.028065124851720098,
#  'compiler-construction': 0.5250412881004836,
#  'gnu': 0.365442285286,
#  'redis': 2.8038415590115855e-06,
#  'microcontroller': 0.4591944243008399,
#  'naudio': 0.5907,
#  'concurrency': 0.10584800625076878,
#  'channel': 0.4093,
#  'goroutine': 0.4093,
#  'panic': 0.4093,
#  'camera': 0.365442285286,
#  'crash': 0.427586821292953,
#  'timer': 0.10701852178983583,
#  'sqlfiddle': 0.4093,
#  'io': 0.1963345359952586,
#  'python-click': 0.4093,
#  'jtable': 0.206110877643,
#  'destructuring': 0.004701651857820438,
#  'razor': 0.2558065312752091,
#  'textbox': 0.01681051215548562,
#  'kendo-asp': 0.4093,
#  'multiline': 0.068568592357,
#  'telerik-mvc': 0.4093,
#  'comparison': 0.1217496954237201,
#  'height': 0.634557714714,
#  'width': 0.634557714714,
#  'google-drive-api': 0.009881530212648783,
#  'base64': 0.1751412608576502,
#  'gson': 0.004509775899336363,
#  'msbuild': 7.852670463220621e-05,
#  'coding-style': 0.4591944243008399,
#  'rstudio': 0.004509775899336363,
#  'r-markdown': 0.0007876512329426371,
#  'margins': 0.365442285286,
#  'instagram': 0.18220935382679682,
#  'instagram-api': 0.04541407432175203,
#  'protocol-buffers': 0.0001787983704061568,
#  ...}

# %% [markdown]
# ## Featurização e Modelagem

# %%
#avg bias feature

def gen_features(data, tag_dict, return_y=True):
    feature_col = []
    Y = []

    for ts, tags, y in data:

        feature_row = []

        for tag in tags:
            if tag not in tag_dict:
                feature_row.append(1)
                continue
            feature_row.append(tag_dict[tag])
            
        feature_col.append(np.mean(feature_row))
        Y.append(y)
        
    feature_col = np.array(feature_col)
    feature_col[np.isnan(feature_col)] = 1. # nan = 1.
    feature_col = feature_col.reshape(-1,1) #sklearn
    
    Y = np.array(Y)
        
    if return_y:
        return feature_col, Y
    return feature_col

# %%
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_scorea
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-cfadd1580be3> in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 #from lightgbm import LGBMClassifier
# ----> 3 from sklearn.metrics import roc_auc_scorea
#
# ImportError: cannot import name 'roc_auc_scorea' from 'sklearn.metrics' (R:\Install\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)

# %%
feature_col_tag_like_tr, Y_tr = gen_features(train, tag_like)
feature_col_tag_like_ts, Y_ts = gen_features(test, tag_like)

mdl = LGBMClassifier(random_state=0)
mdl.fit(feature_col_tag_like_tr, Y_tr)

raw_roc = roc_auc_score(Y_ts, feature_col_tag_like_ts)
model_roc = roc_auc_score(Y_ts, mdl.predict_proba(feature_col_tag_like_ts)[:,1])
print("ROC AUC - Feature = {} - Model = {}".format(raw_roc, model_roc))

# %% [markdown]
# # Fim
